# %%
from utils import *

# %%
uniqcounts, samplemap, sig, ratio, cov = load_and_preprocess_data()

# %%
train_samples, test_samples = train_test(samplemap, include_hn=True)

# %%
pipeline_sequ_selection(uniqcounts, train_samples, test_samples, forward=True)
# Out:
# Initially using 960 features
# keeping 4 features : [40 121 313 672]
# Metrics on train
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88        23
#            1       0.58      1.00      0.74         7
#
#     accuracy                           0.83        30
#    macro avg       0.79      0.89      0.81        30
# weighted avg       0.90      0.83      0.85        30
#
# Metrics on test
#               precision    recall  f1-score   support
#
#            0       0.47      0.67      0.55        27
#            1       0.57      0.38      0.45        32
#
#     accuracy                           0.51        59
#    macro avg       0.52      0.52      0.50        59
# weighted avg       0.53      0.51      0.50        59
